# %%
import pandas as pd

# %%
# Set display option to show full text in all columns
pd.set_option('display.max_colwidth', None)

# %%
# Read dataset
df = pd.read_csv('../dataset/validation.csv')

# Display the first few rows of the dataframe to check
display(df)
# Out:
#                                                                                                                                                                                                  text  \
# 0                                                                                                                               im feeling quite sad and sorry for myself but ill snap out of it soon
# 1                                                                                                                              i feel like i am still looking at a blank canvas blank pieces of paper
# 2                                                                                                                                                                      i feel like a faithful servant
# ...

# %%
# Add an incremental ID column
df['ID'] = range(1, len(df) + 1)

# Display the first few rows of the dataframe to check
display(df)
# Out:
#                                                                                                                                                                                                  text  \
# 0                                                                                                                               im feeling quite sad and sorry for myself but ill snap out of it soon
# 1                                                                                                                              i feel like i am still looking at a blank canvas blank pieces of paper
# 2                                                                                                                                                                      i feel like a faithful servant
# ...

# %%
# Store the updated DataFrame into a new CSV file
df.to_csv('../dataset/human_vs_machine_experiment.csv', index=False)
